# %% [markdown]
# <a href="https://colab.research.google.com/github/otikuoY/texas-education-opportunity-data-analysis/blob/main/notebooks/texas_education_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

base = "/content/drive/MyDrive/nyu-data-project"

folders = [
    "data/raw",
    "data/clean",
    "notebooks",
    "charts",
    "report"
]

for folder in folders:
    os.makedirs(os.path.join(base, folder), exist_ok=True)

print("Project folders created successfully.")
# Out:
# Project folders created successfully.

# %%
readme_text = """# Private School Access and Education Opportunity in Texas

## Overview
This project analyzes how private-school access varies across Texas counties and how it relates to income and public-school outcomes.

## Research Question
How does private-school access vary across Texas counties, and how is it related to income and public-school outcomes?

## Data Sources
- NCES Private School Universe Survey
- Texas Academic Performance Reports
- U.S. Census ACS 5-Year Data

## Methods
- Data cleaning
- County-level aggregation
- Data visualization
- Correlation analysis
- Simple regression analysis

## Tools
Python, pandas, matplotlib, Google Colab, GitHub
"""

with open(base + "/README.md", "w") as f:
    f.write(readme_text)

print("README.md created.")
# Out:
# README.md created.

# %%
report_text = """# Private School Access and Education Opportunity in Texas

## Abstract

## Introduction

## Research Question

## Data Sources

## Methods

## Findings

## Limitations

## Conclusion

## Future Work
"""

with open(base + "/report/final_report.md", "w") as f:
    f.write(report_text)

print("final_report.md created.")
# Out:
# final_report.md created.

# %%
for root, dirs, files in os.walk(base):
    level = root.replace(base, '').count(os.sep)
    indent = ' ' * 4 * level
    print(f"{indent}{os.path.basename(root)}/")
    subindent = ' ' * 4 * (level + 1)
    for file in files:
        print(f"{subindent}{file}")
# Out:
# nyu-data-project/
#     README.md
#     data/
#         raw/
#         clean/
#     notebooks/
#     charts/
#     report/
#         final_report.md
